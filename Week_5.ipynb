# %% [markdown]
# <a href="https://colab.research.google.com/github/srijan-27/Cureya/blob/main/Week_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cureya Week-5 Task: STOCK PRICE PREDICTION
#
# > **Executed By: Srijan Rastogi | srastogi751@gmail.com**

# %% [markdown]
# ### **Importing the Libraries**

# %%
import pandas_datareader as web
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split
from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# ### **Loading the Dataset**

# %%
url = "https://raw.githubusercontent.com/srijan-27/Cureya/main/AAPL.csv"
test = pd.read_csv(url)
test_df = test
test
# Out:
#             Date       Open       High  ...      Close  Adj Close     Volume
# 0     2012-01-03  14.621429  14.732143  ...  14.686786  12.610315  302220800
# 1     2012-01-04  14.642857  14.810000  ...  14.765714  12.678085  260022000
# 2     2012-01-05  14.819643  14.948214  ...  14.929643  12.818838  271269600
# 3     2012-01-06  14.991786  15.098214  ...  15.085714  12.952841  318292800
# 4     2012-01-09  15.196429  15.276786  ...  15.061786  12.932299  394024400
# ...          ...        ...        ...  ...        ...        ...        ...
# 1998  2019-12-11  67.202499  67.775002  ...  67.692497  66.799057   78756800
# 1999  2019-12-12  66.945000  68.139999  ...  67.864998  66.969292  137310400
# 2000  2019-12-13  67.864998  68.824997  ...  68.787498  67.879601  133587600
# 2001  2019-12-16  69.250000  70.197502  ...  69.964996  69.041557  128186000
# 2002  2019-12-17  69.892502  70.442497  ...  70.102501  69.177261  114158400
#
# [2003 rows x 7 columns]

# %% [markdown]
# ### **Data Visualization**

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in test:
    if plotnumber<=7 :
        ax = plt.subplot(3, 3, plotnumber)
        sns.scatterplot(x = test['Close'], y = test[column])
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(22,8))
plt.scatter(test.index,test["Close"],color="pink",lw=3)
plt.plot(test.index,test["Close"])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(22,8))
plt.scatter(test.index,test["Volume"],color="red",lw=3)
plt.plot(test.index,test["Volume"])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(22,8))
plt.scatter(test.index,test["Date"],color="yellow",lw=3)
plt.plot(test.index,test["Date"])
plt.show()

# %%
fig, ax1 = plt.subplots(3,2, figsize=(20,25))
k = 1
columns = list(test.columns)
for i in range(3):
    for j in range(2):
            sns.distplot(test[columns[k]], ax = ax1[i][j], color = 'blue')
            ax1[i][j].grid(True)
            k += 1
plt.show()

# %%
def log_transform(col):
    return np.log(col[0])

test["Adj Close"]=test[["Adj Close"]].apply(log_transform, axis=1)

sns.distplot(test["Adj Close"], color = 'blue')
plt.grid(False)
plt.show()

# %%
test.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999775  0.999709  0.999480   0.979787 -0.562159
# High       0.999775  1.000000  0.999646  0.999739   0.979901 -0.559032
# Low        0.999709  0.999646  1.000000  0.999763   0.980076 -0.567760
# Close      0.999480  0.999739  0.999763  1.000000   0.980102 -0.563906
# Adj Close  0.979787  0.979901  0.980076  0.980102   1.000000 -0.627271
# Volume    -0.562159 -0.559032 -0.567760 -0.563906  -0.627271  1.000000

# %%
fig, ax = plt.subplots(figsize=(20,12))
sns.heatmap(test.corr(), center=0, cmap='RdBu')
ax.set_title('Multi-Collinearity of Stock Attributes')
# Out:
# Text(0.5, 1.0, 'Multi-Collinearity of Stock Attributes')

# %%
corr=abs(test.corr())
plt.figure(figsize=(10,6))
plt.plot(corr["Adj Close"].sort_values(ascending=False)[1:],label="Correlation",color="green")
plt.ylabel("Correlation")
plt.xlabel("Feature")
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
sns.pairplot(test)

# %%
plt.figure(figsize = (20, 8))
sns.boxplot(data = test, width = 0.8)
plt.show()

# %%
test.hist(figsize=(20,10), layout=(2,6))
plt.show()

# %%
data = test.filter(['Close'])
dataset = data.values
len(dataset)
# Out:
# 2003

# %%
dataset
# Out:
# array([[14.686786],
#        [14.765714],
#        [14.929643],
#        ...,
#        [68.787498],
#        [69.964996],
#        [70.102501]])

# %%
data
# Out:
#           Close
# 0     14.686786
# 1     14.765714
# 2     14.929643
# 3     15.085714
# 4     15.061786
# ...         ...
# 1998  67.692497
# 1999  67.864998
# 2000  68.787498
# 2001  69.964996
# 2002  70.102501
#
# [2003 rows x 1 columns]

# %% [markdown]
# ### **Fixing Training Data Size**

# %%
training_data_len = math.ceil(len(dataset)*.8)
training_data_len
# Out:
# 1603

# %% [markdown]
# ### **Data Normalization**

# %% [markdown]
# **Using MinMax Scaler to scale the data between 0 & 1**

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
print(scaled_data.shape)
print(scaled_data)
# Out:
# (2003, 1)
# [[0.0131651 ]
#  [0.01457063]
#  [0.01748986]
#  ...
#  [0.97658262]
#  [0.99755133]
#  [1.        ]]

# %% [markdown]
# ### **Splitting the Dataset**

# %%
train_data = scaled_data[0:training_data_len, :]
print(len(train_data))
x_train, y_train = [], []

for i in range(100, len(train_data)):
  x_train.append(train_data[i-100:i, 0])
  y_train.append(train_data[i,0])
  if i<=101:
    print(x_train)
    print(y_train)
# Out:
# 1603
# [array([0.0131651 , 0.01457063, 0.01748986, 0.02026915, 0.01984304,
#        0.02080338, 0.02036454, 0.0196268 , 0.01862192, 0.02173194,
#        0.02453667, 0.02367173, 0.01893356, 0.02345549, 0.01900353,
#        0.03569839, 0.03440732, 0.03609271, 0.03973694, 0.04194383,
#        0.04175942, 0.04107891, 0.04397904, 0.04670743, 0.0497984 ,
#        0.05479095, 0.0652785 , 0.0654375 , 0.07127595, 0.07563886,
#        0.0681405 , 0.07102789, 0.07097067, 0.07906688, 0.07791571,
#        0.08004628, 0.08387497, 0.08600557, 0.09214292, 0.09661394,
#        0.09790501, 0.0983566 , 0.09071196, 0.08886754, 0.08914104,
#        0.09632779, 0.09835024, 0.10269409, 0.11293359, 0.12659476,
#        0.12403805, 0.12404441, 0.13392141, 0.13701237, 0.1348118 ,
#        0.13280208, 0.13070964, 0.13766104, 0.14243104, 0.14442806,
#        0.13949272, 0.13293562, 0.14507041, 0.15186918, 0.14868284,
#        0.15464215, 0.15626391, 0.15130952, 0.14988489, 0.14770341,
#        0.13654805, 0.12058461, 0.13939097, 0.13852602, 0.12523373,
#        0.11603725, 0.11522315, 0.10796011, 0.13958174, 0.13811897,
#        0.13512978, 0.12303317, 0.12185661, 0.12430515, 0.12165942,
#        0.111121  , 0.11381127, 0.11298447, 0.11362044, 0.11447267,
#        0.11204956, 0.10664995, 0.10343818, 0.09892898, 0.08877852,
#        0.08894385, 0.10859608, 0.10585499, 0.11449815, 0.11116554])]
# [0.1092384452098932]
# [array([0.0131651 , 0.01457063, 0.01748986, 0.02026915, 0.01984304,
#        0.02080338, 0.02036454, 0.0196268 , 0.01862192, 0.02173194,
#        0.02453667, 0.02367173, 0.01893356, 0.02345549, 0.01900353,
#        0.03569839, 0.03440732, 0.03609271, 0.03973694, 0.04194383,
#        0.04175942, 0.04107891, 0.04397904, 0.04670743, 0.0497984 ,
#        0.05479095, 0.0652785 , 0.0654375 , 0.07127595, 0.07563886,
#        0.0681405 , 0.07102789, 0.07097067, 0.07906688, 0.07791571,
#        0.08004628, 0.08387497, 0.08600557, 0.09214292, 0.09661394,
#        0.09790501, 0.0983566 , 0.09071196, 0.08886754, 0.08914104,
#        0.09632779, 0.09835024, 0.10269409, 0.11293359, 0.12659476,
#        0.12403805, 0.12404441, 0.13392141, 0.13701237, 0.1348118 ,
#        0.13280208, 0.13070964, 0.13766104, 0.14243104, 0.14442806,
#        0.13949272, 0.13293562, 0.14507041, 0.15186918, 0.14868284,
#        0.15464215, 0.15626391, 0.15130952, 0.14988489, 0.14770341,
#        0.13654805, 0.12058461, 0.13939097, 0.13852602, 0.12523373,
#        0.11603725, 0.11522315, 0.10796011, 0.13958174, 0.13811897,
#        0.13512978, 0.12303317, 0.12185661, 0.12430515, 0.12165942,
#        0.111121  , 0.11381127, 0.11298447, 0.11362044, 0.11447267,
#        0.11204956, 0.10664995, 0.10343818, 0.09892898, 0.08877852,
#        0.08894385, 0.10859608, 0.10585499, 0.11449815, 0.11116554]), array([0.01457063, 0.01748986, 0.02026915, 0.01984304, 0.02080338,
#        0.02036454, 0.0196268 , 0.01862192, 0.02173194, 0.02453667,
#        0.02367173, 0.01893356, 0.02345549, 0.01900353, 0.03569839,
#        0.03440732, 0.03609271, 0.03973694, 0.04194383, 0.04175942,
#        0.04107891, 0.04397904, 0.04670743, 0.0497984 , 0.05479095,
#        0.0652785 , 0.0654375 , 0.07127595, 0.07563886, 0.0681405 ,
#        0.07102789, 0.07097067, 0.07906688, 0.07791571, 0.08004628,
#        0.08387497, 0.08600557, 0.09214292, 0.09661394, 0.09790501,
#        0.0983566 , 0.09071196, 0.08886754, 0.08914104, 0.09632779,
#        0.09835024, 0.10269409, 0.11293359, 0.12659476, 0.12403805,
#        0.12404441, 0.13392141, 0.13701237, 0.1348118 , 0.13280208,
#        0.13070964, 0.13766104, 0.14243104, 0.14442806, 0.13949272,
#        0.13293562, 0.14507041, 0.15186918, 0.14868284, 0.15464215,
#        0.15626391, 0.15130952, 0.14988489, 0.14770341, 0.13654805,
#        0.12058461, 0.13939097, 0.13852602, 0.12523373, 0.11603725,
#        0.11522315, 0.10796011, 0.13958174, 0.13811897, 0.13512978,
#        0.12303317, 0.12185661, 0.12430515, 0.12165942, 0.111121  ,
#        0.11381127, 0.11298447, 0.11362044, 0.11447267, 0.11204956,
#        0.10664995, 0.10343818, 0.09892898, 0.08877852, 0.08894385,
#        0.10859608, 0.10585499, 0.11449815, 0.11116554, 0.10923845])]
# [0.1092384452098932, 0.11558566261979056]

# %%
test_data = scaled_data[training_data_len: , :]
print(len(test_data))
x_test, y_test = [], []

for i in range(100, len(test_data)):
  x_test.append(test_data[i-100:i, 0])
  y_test.append(train_data[i,0])
  if i<=101:
    print(x_test)
    print(y_test)
# Out:
#        0.60564508, 0.61223397, 0.61521678, 0.61290181, 0.60506631,
#        0.60297388, 0.60764846, 0.60061434, 0.60105957, 0.59233369,
#        0.59188853, 0.57831004, 0.58191611, 0.57728611, 0.57488201,
#        0.56263911, 0.57270052, 0.57149854, 0.57746415, 0.57572789,
#        0.58494341, 0.57043005, 0.57701892, 0.5884605 , 0.60008012,
#        0.59905621, 0.58805984, 0.60208351, 0.6034191 , 0.60154929,
#        0.60395331, 0.59927874, 0.60586769, 0.60390883, 0.60466565,
#        0.61085388, 0.61895648, 0.61624079, 0.60186089, 0.59709733,
#        0.59878902, 0.64869556, 0.67491763, 0.67758882, 0.68239696,
#        0.67367108, 0.67429435, 0.68155107, 0.6755409 , 0.68150651,
#        0.68542426, 0.68760574, 0.7013178 , 0.72028313, 0.71084501,
#        0.70897511, 0.70901968, 0.71097855, 0.71396136, 0.72188586,
#        0.72972128, 0.74432372, 0.75345026, 0.76502538, 0.7682753 ,
#        0.76164185, 0.744858  , 0.73684445, 0.7236221 , 0.74819698,
#        0.73582052, 0.75959399, 0.7481524 , 0.72161874, 0.72322145,
#        0.72380017, 0.73119044, 0.72063931, 0.7345739 , 0.7408067 ,
#        0.73292671, 0.75309408, 0.75661117, 0.76337812, 0.7723711 ,
#        0.78479211, 0.76662809, 0.75015577, 0.7478408 , 0.76164185])]
# [0.1092384452098932, 0.11558566261979056]

# %% [markdown]
# ### **Shaping Training & Testing Data**

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1], 1))
print(x_train.shape, y_train.shape)
# Out:
# (1503, 100, 1) (1503,)

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
print(x_test.shape, y_test.shape)
# Out:
# (300, 100, 1) (300,)

# %% [markdown]
# ### **RNN Model (LSTM)**

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))

# %% [markdown]
# **Compiling the Model**

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Training the Model**

# %%
lstm_model = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size = 64, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 10s 226ms/step - loss: 0.0130 - val_loss: 0.3627
# Epoch 2/100
# 24/24 [==============================] - 4s 169ms/step - loss: 0.0011 - val_loss: 0.3943
# Epoch 3/100
# 24/24 [==============================] - 4s 164ms/step - loss: 5.1551e-04 - val_loss: 0.3286
# Epoch 4/100
# 24/24 [==============================] - 4s 165ms/step - loss: 4.6130e-04 - val_loss: 0.3423
# Epoch 5/100
# 24/24 [==============================] - 4s 162ms/step - loss: 4.9974e-04 - val_loss: 0.3218
# Epoch 6/100
# 24/24 [==============================] - 4s 166ms/step - loss: 4.5127e-04 - val_loss: 0.3546
# Epoch 7/100
# 24/24 [==============================] - 4s 162ms/step - loss: 4.2871e-04 - val_loss: 0.3303
# Epoch 8/100
# 24/24 [==============================] - 4s 162ms/step - loss: 4.3597e-04 - val_loss: 0.3462
# Epoch 9/100
# 24/24 [==============================] - 4s 166ms/step - loss: 4.0117e-04 - val_loss: 0.3446
# Epoch 10/100
# 24/24 [==============================] - 4s 165ms/step - loss: 4.2001e-04 - val_loss: 0.3479
# Epoch 11/100
# 24/24 [==============================] - 4s 163ms/step - loss: 3.9223e-04 - val_loss: 0.3554
# Epoch 12/100
# 24/24 [==============================] - 4s 168ms/step - loss: 3.7843e-04 - val_loss: 0.3529
# Epoch 13/100
# 24/24 [==============================] - 4s 166ms/step - loss: 3.8296e-04 - val_loss: 0.3294
# Epoch 14/100
100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.9458e-04 - val_loss: 0.3428
# Epoch 47/100
# 24/24 [==============================] - 4s 169ms/step - loss: 2.1564e-04 - val_loss: 0.3281
# Epoch 48/100
# 24/24 [==============================] - 4s 164ms/step - loss: 1.9838e-04 - val_loss: 0.3446
# Epoch 49/100
# 24/24 [==============================] - 4s 170ms/step - loss: 1.8410e-04 - val_loss: 0.3418
# Epoch 50/100
# 24/24 [==============================] - 4s 173ms/step - loss: 1.9327e-04 - val_loss: 0.3425
# Epoch 51/100
# 24/24 [==============================] - 4s 164ms/step - loss: 1.8935e-04 - val_loss: 0.3229
# Epoch 52/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.8735e-04 - val_loss: 0.3556
# Epoch 53/100
# 24/24 [==============================] - 4s 170ms/step - loss: 1.8848e-04 - val_loss: 0.3444
# Epoch 54/100
# 24/24 [==============================] - 4s 163ms/step - loss: 1.7595e-04 - val_loss: 0.3289
# Epoch 55/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.6815e-04 - val_loss: 0.3182
# Epoch 56/100
# 24/24 [==============================] - 4s 170ms/step - loss: 1.8064e-04 - val_loss: 0.3368
# Epoch 57/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.5580e-04 - val_loss: 0.3405
# Epoch 58/100
# 24/24 [==============================] - 4s 168ms/step - loss: 1.5189e-04 - val_loss: 0.3532
# Epoch 59/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.5582e-04 - val_loss: 0.3492
# Epoch 60/100
# 24/24 [==============================] - 4s 167ms/step - loss: 1.5777e-04 - val_loss: 0.3436
# Epoch 61/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.5010e-04 - val_loss: 0.3360
# Epoch 62/100
# 24/24 [==============================] - 4s 164ms/step - loss: 1.4615e-04 - val_loss: 0.3318
# Epoch 63/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.4117e-04 - val_loss: 0.3523
# Epoch 64/100
# 24/24 [==============================] - 4s 169ms/step - loss: 1.4225e-04 - val_loss: 0.3678
# Epoch 65/100
# 24/24 [==============================] - 4s 163ms/step - loss: 1.5130e-04 - val_loss: 0.3616
# Epoch 66/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.4131e-04 - val_loss: 0.3408
# Epoch 67/100
# 24/24 [==============================] - 4s 167ms/step - loss: 1.2986e-04 - val_loss: 0.3375
# Epoch 68/100
# 24/24 [==============================] - 4s 168ms/step - loss: 1.4127e-04 - val_loss: 0.3318
# Epoch 69/100
# 24/24 [==============================] - 4s 171ms/step - loss: 1.3592e-04 - val_loss: 0.3303
# Epoch 70/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.4578e-04 - val_loss: 0.3434
# Epoch 71/100
# 24/24 [==============================] - 4s 171ms/step - loss: 1.2540e-04 - val_loss: 0.3339
# Epoch 72/100
# 24/24 [==============================] - 4s 169ms/step - loss: 1.2073e-04 - val_loss: 0.3386
# Epoch 73/100
# 24/24 [==============================] - 4s 163ms/step - loss: 1.2298e-04 - val_loss: 0.3530
# Epoch 74/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.2518e-04 - val_loss: 0.3591
# Epoch 75/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.2432e-04 - val_loss: 0.3591
# Epoch 76/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.4488e-04 - val_loss: 0.3633
# Epoch 77/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.2825e-04 - val_loss: 0.3354
# Epoch 78/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.2337e-04 - val_loss: 0.3639
# Epoch 79/100
# 24/24 [==============================] - 4s 164ms/step - loss: 1.3415e-04 - val_loss: 0.3475
# Epoch 80/100
# 24/24 [==============================] - 4s 169ms/step - loss: 1.1975e-04 - val_loss: 0.3490
# Epoch 81/100
# 24/24 [==============================] - 4s 173ms/step - loss: 1.1934e-04 - val_loss: 0.3531
# Epoch 82/100
# 24/24 [==============================] - 4s 172ms/step - loss: 1.1395e-04 - val_loss: 0.3525
# Epoch 83/100
# 24/24 [==============================] - 4s 175ms/step - loss: 1.1493e-04 - val_loss: 0.3429
# Epoch 84/100
# 24/24 [==============================] - 4s 164ms/step - loss: 1.1056e-04 - val_loss: 0.3485
# Epoch 85/100
# 24/24 [==============================] - 4s 168ms/step - loss: 1.1783e-04 - val_loss: 0.3466
# Epoch 86/100
# 24/24 [==============================] - 4s 168ms/step - loss: 1.1144e-04 - val_loss: 0.3357
# Epoch 87/100
# 24/24 [==============================] - 4s 163ms/step - loss: 1.1031e-04 - val_loss: 0.3559
# Epoch 88/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.1328e-04 - val_loss: 0.3605
# Epoch 89/100
# 24/24 [==============================] - 4s 171ms/step - loss: 1.6179e-04 - val_loss: 0.3628
# Epoch 90/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.1801e-04 - val_loss: 0.3683
# Epoch 91/100
# 24/24 [==============================] - 4s 172ms/step - loss: 1.0270e-04 - val_loss: 0.3511
# Epoch 92/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.0275e-04 - val_loss: 0.3515
# Epoch 93/100
# 24/24 [==============================] - 4s 163ms/step - loss: 1.0047e-04 - val_loss: 0.3435
# Epoch 94/100
# 24/24 [==============================] - 4s 168ms/step - loss: 9.7738e-05 - val_loss: 0.3391
# Epoch 95/100
# 24/24 [==============================] - 4s 164ms/step - loss: 9.4625e-05 - val_loss: 0.3549
# Epoch 96/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.2386e-04 - val_loss: 0.3587
# Epoch 97/100
# 24/24 [==============================] - 4s 169ms/step - loss: 1.1246e-04 - val_loss: 0.3431
# Epoch 98/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.2112e-04 - val_loss: 0.3509
# Epoch 99/100
# 24/24 [==============================] - 4s 170ms/step - loss: 9.4296e-05 - val_loss: 0.3339
# Epoch 100/100
# 24/24 [==============================] - 4s 168ms/step - loss: 1.0592e-04 - val_loss: 0.3404

# %% [markdown]
# **Visualizing Loss**

# %%
plt.plot(lstm_model.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# **Predicting Values**

# %%
train_predictions = model.predict(x_train)
test_predictions = model.predict(x_test)

# %%
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

# %%
print(train_predictions.shape, test_predictions.shape)
# Out:
# (1503, 1) (300, 1)

# %% [markdown]
# ### **Evaluation Metrics**

# %%
math.sqrt(mean_squared_error(y_train,train_predictions))
# Out:
# 28.1546154447878

# %%
math.sqrt(mean_squared_error(y_test,test_predictions))
# Out:
# 50.43842655723445

# %% [markdown]
# ### **Visualising the Predicted Values**

# %%
# train predictions
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[100:len(train_predictions)+100, :] = train_predictions
# test predictions
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predictions)+(100*2):len(dataset), :] = test_predictions

plt.figure(figsize = (19,9))
plt.title('RNN model LSTM')
plt.ylabel('Close Price in $', fontsize = 20)

plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend(['Data', 'Train', 'Predictions'], loc='lower right')
plt.show()
